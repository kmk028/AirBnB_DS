# %%
from ipynb.fs.full.Tokyo_V2 import *
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
from collections import OrderedDict,Counter
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('en_core_web_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm
             
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight
        
        """return top number keywords"""
        kw = []
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
           # print(key + ' - ' + str(value))
            if value > 1:
                kw.append(key)
        return ' '.join(kw)

# %%
tr4w = TextRank4Keyword()
analyser = lambda x: tr4w.analyze(x, candidate_pos = ['NOUN', 'PROPN'], window_size=5, lower=False)

# %%
listings_clean['summary'] = listings_clean['summary'].dropna()

# %%
listings_clean['KW'] = listings_clean['summary'].apply(analyser)

# %%
# convert to lower case, remove numbers and punctuation and strip non-ASCII characters
import re
import string
listings_clean['KW'] = listings_clean['KW'].apply(lambda x:str.lower(x))
listings_clean['KW'] = listings_clean['KW'].apply(lambda x:re.sub("([^\x00-\x7F])+"," ",x))
listings_clean['KW'] = listings_clean['KW'].apply(lambda x:x.translate(str.maketrans('', '', string.punctuation)))
listings_clean['KW'] = listings_clean['KW'].apply(lambda x:''.join(i for i in x if not i.isdigit()))

# %%
# Join all summries to single string and then find the count of most repeated words. 
words = (listings_clean['KW'].str.cat(sep=" ")).split()
word_counts = Counter(words)
for word, count in word_counts.most_common():
    if count > 25:
        print(f'{word} is repeated {count} times.')
# Out:
# station is repeated 3571 times.
# tokyo is repeated 2404 times.
# room is repeated 2278 times.
# shinjuku is repeated 1658 times.
# line is repeated 1316 times.
# minutes is repeated 1238 times.
# house is repeated 1127 times.
# min is repeated 1048 times.
# walk is repeated 978 times.
# asakusa is repeated 839 times.
# bed is repeated 820 times.
# area is repeated 791 times.
# jr is repeated 788 times.
# airport is repeated 763 times.
# mins is repeated 721 times.
# apartment is repeated 719 times.
# ikebukuro is repeated 719 times.
# access is repeated 687 times.
# shibuya is repeated 643 times.
# rooms is repeated 629 times.
# restaurants is repeated 588 times.
# shopping is repeated 585 times.
# kitchen is repeated 581 times.
# stores is repeated 578 times.
# hotel is repeated 571 times.
# ueno is repeated 566 times.
# convenience is repeated 510 times.
# akihabara is repeated 499 times.
# floor is repeated 483 times.
# haneda is repeated 479 times.
# train is repeated 478 times.
# bathroom is repeated 464 times.
# ginza is repeated 443 times.
# foot is repeated 390 times.
# store is repeated 375 times.
# guests is repeated 369 times.
# building is repeated 366 times.
# narita is repeated 334 times.
# place is repeated 329 times.
# sta is repeated 328 times.
# tv is repeated 321 times.
# people is repeated 307 times.
# wi is repeated 303 times.
# toilet is repeated 300 times.
# metro is repeated 299 times.
# shops is repeated 297 times.
# air is repeated 297 times.
# shower is repeated 293 times.
# fi is repeated 292 times.
# japan is repeated 292 times.
# beds is repeated 285 times.
# wifi is repeated 280 times.
# microwave is repeated 273 times.
# hostel is repeated 269 times.
# city is repeated 264 times.
# street is repeated 261 times.
# style is repeated 249 times.
# roppongi is repeated 244 times.
# machine is repeated 242 times.
# family is repeated 239 times.
# conditioner is repeated 239 times.
# harajuku is repeated 235 times.
# minute is repeated 235 times.
# yamanote is repeated 234 times.
# home is repeated 229 times.
# center is repeated 229 times.
# living is repeated 227 times.
# sky is repeated 224 times.
# subway is repeated 215 times.
# guest is repeated 207 times.
# space is repeated 205 times.
# stay is repeated 200 times.
# airbnb is repeated 199 times.
# sofa is repeated 199 times.
# number is repeated 198 times.
# washing is repeated 196 times.
# accommodation is repeated 195 times.
# temple is repeated 194 times.
# bath is repeated 189 times.
# location is repeated 188 times.
# check is repeated 187 times.
# bus is repeated 187 times.
# market is repeated 187 times.
# okubo is repeated 183 times.
# dryer is repeated 183 times.
# size is repeated 178 times.
# luxury is repeated 176 times.
# business is repeated 174 times.
# refrigerator is repeated 174 times.
# tourist is repeated 172 times.
# sightseeing is repeated 171 times.
# property is repeated 166 times.
# travelers is repeated 161 times.
# holiday is repeated 153 times.
# spots is repeated 152 times.
# otsuka is repeated 152 times.
# park is repeated 149 times.
# nishi is repeated 149 times.
# drug is repeated 147 times.
# supermarkets is repeated 146 times.
# screen is repeated 146 times.
# dining is repeated 144 times.
# town is repeated 144 times.
# shin is repeated 144 times.
# hair is repeated 142 times.
# tree is repeated 141 times.
# couples is repeated 141 times.
# skytree is repeated 138 times.
# time is repeated 135 times.
# term is repeated 134 times.
# free is repeated 134 times.
# facilities is repeated 133 times.
# group is repeated 131 times.
# exit is repeated 131 times.
# distance is repeated 130 times.
# towel is repeated 129 times.
# cm is repeated 128 times.
# lots is repeated 125 times.
# body is repeated 125 times.
# m is repeated 124 times.
# ryogoku is repeated 124 times.
# kettle is repeated 123 times.
# shampoo is repeated 121 times.
# restaurant is repeated 121 times.
# friends is repeated 119 times.
# stations is repeated 118 times.
# type is repeated 117 times.
# coffee is repeated 115 times.
# service is repeated 115 times.
# food is repeated 112 times.
# fridge is repeated 111 times.
# website is repeated 110 times.
# oedo is repeated 109 times.
# desk is repeated 108 times.
# art is repeated 108 times.
# staff is repeated 107 times.
# bedroom is repeated 106 times.
# tsukiji is repeated 104 times.
# shinagawa is repeated 104 times.
# system is repeated 102 times.
# km is repeated 101 times.
# lines is repeated 101 times.
# toothbrush is repeated 101 times.
# supermarket is repeated 100 times.
# bedrooms is repeated 96 times.
# nippori is repeated 95 times.
# culture is repeated 95 times.
# bars is repeated 94 times.
# phone is repeated 93 times.
# higashi is repeated 92 times.
# furniture is repeated 92 times.
# sensoji is repeated 91 times.
# toei is repeated 90 times.
# amenities is repeated 90 times.
# comfy is repeated 90 times.
# tatami is repeated 89 times.
# government is repeated 89 times.
# parts is repeated 88 times.
# tower is repeated 87 times.
# night is repeated 87 times.
# variety is repeated 86 times.
# lady is repeated 86 times.
# soap is repeated 85 times.
# person is repeated 85 times.
# akasaka is repeated 84 times.
# quality is repeated 84 times.
# toilets is repeated 82 times.
# studio is repeated 81 times.
# kitchenette is repeated 81 times.
# hibiya is repeated 80 times.
# conditioning is repeated 80 times.
# security is repeated 79 times.
# trip is repeated 78 times.
# cafe is repeated 78 times.
# st is repeated 78 times.
# nakano is repeated 78 times.
# museum is repeated 77 times.
# garden is repeated 77 times.
# ebisu is repeated 77 times.
# estate is repeated 76 times.
# oshiage is repeated 75 times.
# hours is repeated 75 times.
# places is repeated 75 times.
# meters is repeated 74 times.
# cafes is repeated 74 times.
# tea is repeated 73 times.
# futon is repeated 73 times.
# towels is repeated 72 times.
# kaminarimon is repeated 72 times.
# children is repeated 70 times.
# shrine is repeated 70 times.
# bathrooms is repeated 70 times.
# spot is repeated 69 times.
# brand is repeated 69 times.
# yokohama is repeated 68 times.
# bar is repeated 67 times.
# downtown is repeated 67 times.
# concept is repeated 67 times.
# week is repeated 67 times.
# north is repeated 67 times.
# grocery is repeated 66 times.
# kuramae is repeated 65 times.
# internet is repeated 64 times.
# goods is repeated 64 times.
# experience is repeated 64 times.
# use is repeated 64 times.
# areas is repeated 63 times.
# privacy is repeated 63 times.
# meiji is repeated 62 times.
# travel is repeated 62 times.
# utensils is repeated 62 times.
# pocket is repeated 61 times.
# travellers is repeated 61 times.
# slippers is repeated 61 times.
# omotesando is repeated 60 times.
# netflix is repeated 60 times.
# shop is repeated 60 times.
# linens is repeated 60 times.
# cooking is repeated 60 times.
# amenity is repeated 60 times.
# marunouchi is repeated 59 times.
# single is repeated 59 times.
# electric is repeated 59 times.
# ride is repeated 58 times.
# east is repeated 58 times.
# west is repeated 58 times.
# laundry is repeated 57 times.
# iriya is repeated 57 times.
# rental is repeated 57 times.
# closet is repeated 57 times.
# district is repeated 56 times.
# cooker is repeated 56 times.
# elevator is repeated 56 times.
# attractions is repeated 56 times.
# coin is repeated 56 times.
# atmosphere is repeated 55 times.
# senso is repeated 55 times.
# balcony is repeated 54 times.
# cho is repeated 54 times.
# mn is repeated 54 times.
# ameyoko is repeated 54 times.
# chair is repeated 53 times.
# keisei is repeated 53 times.
# f is repeated 53 times.
# families is repeated 53 times.
# department is repeated 53 times.
# solo is repeated 53 times.
# floors is repeated 53 times.
# ji is repeated 53 times.
# iron is repeated 52 times.
# keihin is repeated 52 times.
# hairdryer is repeated 51 times.
# mattress is repeated 51 times.
# hustle is repeated 51 times.
# table is repeated 51 times.
# sugamo is repeated 51 times.
# direct is repeated 51 times.
# yoyogi is repeated 50 times.
# japanese is repeated 50 times.
# design is repeated 50 times.
# life is repeated 49 times.
# sanchome is repeated 49 times.
# dormitory is repeated 49 times.
# bakuro is repeated 49 times.
# yokoyama is repeated 49 times.
# neighborhood is repeated 48 times.
# breakfast is repeated 48 times.
# groups is repeated 48 times.
# heart is repeated 47 times.
# ramen is repeated 47 times.
# cherry is repeated 47 times.
# price is repeated 47 times.
# capsule is repeated 47 times.
# copy is repeated 47 times.
# view is repeated 46 times.
# shinjyuku is repeated 46 times.
# world is repeated 46 times.
# entrances is repeated 46 times.
# freewi is repeated 46 times.
# museums is repeated 46 times.
# luggage is repeated 45 times.
# gyoen is repeated 45 times.
# apartments is repeated 45 times.
# b is repeated 45 times.
# rice is repeated 45 times.
# set is repeated 45 times.
# company is repeated 44 times.
# national is repeated 44 times.
# storage is repeated 44 times.
# light is repeated 44 times.
# metropolitan is repeated 43 times.
# stop is repeated 43 times.
# dishes is repeated 43 times.
# couple is repeated 42 times.
# route is repeated 42 times.
# gochome is repeated 42 times.
# sharing is repeated 42 times.
# transfer is repeated 42 times.
# box is repeated 42 times.
# hikifune is repeated 41 times.
# music is repeated 41 times.
# don is repeated 41 times.
# razor is repeated 41 times.
# tourism is repeated 41 times.
# airports is repeated 40 times.
# bedding is repeated 40 times.
# drugstore is repeated 40 times.
# washlet is repeated 40 times.
# gas is repeated 40 times.
# choice is repeated 40 times.
# minowa is repeated 40 times.
# traveler is repeated 40 times.
# tohoku is repeated 40 times.
# stationmin is repeated 40 times.
# disney is repeated 39 times.
# speed is repeated 39 times.
# koenji is repeated 39 times.
# kinshicho is repeated 39 times.
# stove is repeated 39 times.
# quijote is repeated 39 times.
# heater is repeated 38 times.
# ku is repeated 38 times.
# transportation is repeated 38 times.
# day is repeated 38 times.
# pot is repeated 38 times.
# keikyu is repeated 38 times.
# bathtub is repeated 38 times.
# new is repeated 37 times.
# express is repeated 37 times.
# need is repeated 37 times.
# water is repeated 37 times.
# con is repeated 37 times.
# shimokitazawa is repeated 36 times.
# loft is repeated 36 times.
# vacation is repeated 36 times.
# designer is repeated 36 times.
# kamata is repeated 36 times.
# gate is repeated 36 times.
# information is repeated 36 times.
# site is repeated 36 times.
# mt is repeated 36 times.
# equipment is repeated 36 times.
# date is repeated 36 times.
# address is repeated 35 times.
# fukutoshin is repeated 35 times.
# oven is repeated 35 times.
# locals is repeated 35 times.
# terminal is repeated 35 times.
# fruit is repeated 35 times.
# charge is repeated 34 times.
# kokugikan is repeated 34 times.
# imperial is repeated 34 times.
# kabukicho is repeated 34 times.
# showers is repeated 34 times.
# festival is repeated 34 times.
# base is repeated 34 times.
# outlet is repeated 34 times.
# toothpaste is repeated 34 times.
# tour is repeated 33 times.
# tobu is repeated 33 times.
# clean is repeated 33 times.
# rest is repeated 33 times.
# matsumoto is repeated 33 times.
# bunk is repeated 33 times.
# lock is repeated 32 times.
# seibu is repeated 32 times.
# yurakucho is repeated 32 times.
# clothes is repeated 32 times.
# fashion is repeated 32 times.
# streets is repeated 32 times.
# lot is repeated 31 times.
# fuji is repeated 31 times.
# hand is repeated 31 times.
# hour is repeated 31 times.
# stops is repeated 31 times.
# river is repeated 31 times.
# anime is repeated 31 times.
# uniqlo is repeated 31 times.
# range is repeated 31 times.
# hostels is repeated 31 times.
# checkout is repeated 31 times.
# fire is repeated 31 times.
# hatagaya is repeated 30 times.
# yen is repeated 30 times.
# sunshine is repeated 30 times.
# camera is repeated 30 times.
# x is repeated 30 times.
# listing is repeated 30 times.
# asakusabashi is repeated 30 times.
# edo is repeated 30 times.
# appliances is repeated 30 times.
# ryokan is repeated 30 times.
# bashi is repeated 30 times.
# stall is repeated 30 times.
# sofabed is repeated 30 times.
# budget is repeated 30 times.
# taxi is repeated 29 times.
# yotsuya is repeated 29 times.
# entertainment is repeated 29 times.
# sobu is repeated 29 times.
# washer is repeated 29 times.
# needs is repeated 29 times.
# mall is repeated 29 times.
# prime is repeated 29 times.
# units is repeated 29 times.
# ideal is repeated 29 times.
# residence is repeated 28 times.
# cozy is repeated 28 times.
# trains is repeated 28 times.
# drugstores is repeated 28 times.
# max is repeated 28 times.
# condominium is repeated 28 times.
# ishikawadai is repeated 28 times.
# komagome is repeated 28 times.
# passport is repeated 28 times.
# mega is repeated 28 times.
# tyoko is repeated 28 times.
# tsukichi is repeated 28 times.
# superm is repeated 28 times.
# arkets is repeated 28 times.
# self is repeated 27 times.
# adventurers is repeated 27 times.
# stadium is repeated 27 times.
# nakameguro is repeated 27 times.
# kabuki is repeated 27 times.
# hulu is repeated 27 times.
# rent is repeated 27 times.
# lcd is repeated 27 times.
# videos is repeated 27 times.
# jingu is repeated 26 times.
# hiroo is repeated 26 times.
# owl is repeated 26 times.
# tabata is repeated 26 times.
# persons is repeated 26 times.
# shinbashi is repeated 26 times.
# jizo is repeated 26 times.

# %% [markdown]
# # Add below features
# is close to station,train,yamanote
# is in shinjuku
# is in asakusa
# close to airport, haneda, narita
# is close to ikebukuro?
# close to shibuya?
# close to ueno?
# akihabara,ginza,roppongi,harajuku,temple,shrine,okubo,Otsuka,nishi,tsukiji,ryogoku,shinagawa,kaminarimon,akasaka,ikebukuro

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt

# %%
def show_wordcloud(data, title = None):
    
    
    '''funtion to produce and display wordcloud
        taken 2 arguments
        1.data to produce wordcloud
        2.title of wordcloud'''
    
    
    wordcloud = WordCloud(
        background_color='white',
        stopwords=set(STOPWORDS),
        max_words=250,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud,interpolation="bilinear")
    plt.show()

# %%
show_wordcloud(words)

# %%
listings_clean['KW']=listings_clean['KW'].apply(lambda x:x.split())

# %%
# add new features based on NLP analysis above.
listings_clean['shinjuku']=listings_clean['KW'].apply(lambda x:1 if ('shinjuku') in x else 0)
listings_clean['asakusa']=listings_clean['KW'].apply(lambda x:1 if ('asakusa') in x else 0)
listings_clean['ikebukuro']=listings_clean['KW'].apply(lambda x:1 if ('ikebukuro') in x else 0)
listings_clean['shibuya']=listings_clean['KW'].apply(lambda x:1 if ('shibuya') in x else 0)
listings_clean['ueno']=listings_clean['KW'].apply(lambda x:1 if ('ueno') in x else 0)

# %%
listings_clean['station'] = listings_clean['KW'].apply(lambda x:any(item in x for item in 
                                                                     ['station','train','yamanote']))

# %%
listings_clean['airport'] = listings_clean['KW'].apply(lambda x:any(item in x for item in 
                                                                     ['airport','haneda','narita']))
listings_clean['attractions']=listings_clean['KW'].apply(lambda x:any(item in x for item in 
                                                                      ['akihabara','ginza','roppongi',
                                                                       'harajuku','temple','shrine','okubo',
                                                                       'Otsuka','nishi','tsukiji','ryogoku',
                                                                       'shinagawa','kaminarimon','akasaka',
                                                                        'ikebukuro']))

# %%
listings_clean.replace({False: 0, True: 1}, inplace=True)

# %%
listings_clean = listings_clean.drop(columns = ['host_response_time'],axis=1)

# %%
listings_clean.head()
# Out:
#    host_is_superhost  host_identity_verified neighbourhood_cleansed  \
# 3                  0                       1            Setagaya Ku
# 6                  0                       1            Setagaya Ku
# 7                  1                       1            Shinjuku Ku
# 8                  1                       1             Shibuya Ku
# 9                  1                       1             Mitaka Shi
#
#    is_location_exact property_type        room_type  accommodates  bathrooms  \
# 3                  1     Apartment  Entire home/apt             2        1.0
# 6                  1         House  Entire home/apt             3        1.0
# 7                  1     Apartment  Entire home/apt             3        1.0
# 8                  0     Apartment     Private room             6        1.0
# 9                  1         House     Private room             2        1.5
#
#    bedrooms  beds  ...  oven  single_level  shinjuku  asakusa  ikebukuro  \
# 3       0.0   1.0  ...     0             0         0        0          0
# 6       2.0   2.0  ...     1             0         0        0          0
# 7       1.0   4.0  ...     0             0         1        0          0
# 8       2.0   4.0  ...     0             0         1        0          0
# 9       1.0   1.0  ...     0             0         0        0          0
#
#    shibuya  ueno  station airport  attractions
# 3        1     0        1       0            0
# 6        0     0        1       0            0
# 7        0     0        1       0            0
# 8        1     0        0       0            0
# 9        0     0        0       0            0
#
# [5 rows x 96 columns]
